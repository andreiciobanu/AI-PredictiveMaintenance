# %%
import azureml.dataprep as dprep
from azureml.core import Workspace, Dataset

workspace = Workspace.from_config()
# get the datastore to upload prepared data
datastore = workspace.get_default_datastore()

# create a dataset referencing the cloud location
dataset = Dataset.Tabular.from_parquet_files(datastore.path('data/logs/logs.parquet'))

logs_input_df = dataset.to_pandas_dataframe()
print(logs_input_df.head())
distinct_machines_df=logs_input_df['machineID']
machine_count = distinct_machines_df.count()

print('{0} machine(s)'.format(machine_count))

a=logs_input_df.gr
# Out:
#             timestamp   code     level machineID
# 0 2017-06-28 01:45:52     F1  CRITICAL    M_0007
# 1 2017-06-28 13:00:00  fixed      INFO    M_0007
# 2 2017-06-29 06:44:31     F2  CRITICAL    M_0014
# 3 2017-06-29 16:44:19     F1  CRITICAL    M_0010
# 4 2017-06-30 21:00:00  fixed      INFO    M_0010
# 117 machine(s)
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-33-f6233e4191b5> in <module>
#      16 print('{0} machine(s)'.format(machine_count))
#      17
# ---> 18 a=logs_input_df.groupBy('level')
#      19
#      20
#
# /anaconda/envs/azureml_py36/lib/python3.6/site-packages/pandas/core/generic.py in __getattr__(self, name)
#    4374             if self._info_axis._can_hold_identifiers_and_holds_name(name):
#    4375                 return self[name]
# -> 4376             return object.__getattribute__(self, name)
#    4377
# ...
